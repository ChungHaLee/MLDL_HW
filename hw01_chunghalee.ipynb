# %% [markdown]
# # HW 1

# %% [markdown]
# Name: ChungHa Lee
#
# Student ID: 20232027

# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

auto_dataset = pd.read_csv('Auto.csv')

# %%
auto_dataset
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 387  27.0          4         140.0          86    2790          15.6    82
# 388  44.0          4          97.0          52    2130          24.6    82
# 389  32.0          4         135.0          84    2295          11.6    82
# 390  28.0          4         120.0          79    2625          18.6    82
# 391  31.0          4         119.0          82    2720          19.4    82
#
#      origin                       name
# ...

# %%
# Q5-a. Which of the predictors are quantitative, and which are qualitative? 
# quantitative: mpg, cylinders, displacement, horsepower, weight, acceleration, year
# qualitative: origin, name

# %%
# let's divide predictors to quantitative and qualitative
auto_quanti = auto_dataset[['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year']]
auto_quanti
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 387  27.0          4         140.0          86    2790          15.6    82
# 388  44.0          4          97.0          52    2130          24.6    82
# 389  32.0          4         135.0          84    2295          11.6    82
# 390  28.0          4         120.0          79    2625          18.6    82
# 391  31.0          4         119.0          82    2720          19.4    82
#
# [392 rows x 7 columns]

# %%
auto_quali = auto_dataset[['origin', 'name']]
auto_quali
# Out:
#      origin                       name
# 0         1  chevrolet chevelle malibu
# 1         1          buick skylark 320
# 2         1         plymouth satellite
# 3         1              amc rebel sst
# 4         1                ford torino
# ..      ...                        ...
# 387       1            ford mustang gl
# 388       2                  vw pickup
# 389       1              dodge rampage
# 390       1                ford ranger
# 391       1                 chevy s-10
#
# [392 rows x 2 columns]

# %%
# Q5-b. What is the range of each quantitative predictor? You can answer this using the min() and max() methods in numpy.
# max value of each predictors
auto_quanti.max()
# Out:
# mpg               46.6
# cylinders          8.0
# displacement     455.0
# horsepower       230.0
# weight          5140.0
# acceleration      24.8
# year              82.0
# dtype: float64

# %%
# min value of each predictors
auto_quanti.min()
# Out:
# mpg                9.0
# cylinders          3.0
# displacement      68.0
# horsepower        46.0
# weight          1613.0
# acceleration       8.0
# year              70.0
# dtype: float64

# %%
# so this makes the range of each predictors like the below:

# mpg                         9.0 - 46.6
# cylinders                    3.0 - 8.0
# displacement               68.0 - 455.0
# horsepower                   46 - 230
# weight                      1613 - 5140
# acceleration                8.0 - 24.8
# year                          70.0 - 82.0

# %%
# Q5-c. What is the mean and standard deviation of each quantitative predictor?

# %%
# mean
auto_quanti.mean()
# Out:
# mpg               23.445918
# cylinders          5.471939
# displacement     194.411990
# horsepower       104.469388
# weight          2977.584184
# acceleration      15.541327
# year              75.979592
# dtype: float64

# %%
# std
auto_quanti.std()
# Out:
# mpg               7.805007
# cylinders         1.705783
# displacement    104.644004
# horsepower       38.491160
# weight          849.402560
# acceleration      2.758864
# year              3.683737
# dtype: float64

# %%
# Q5-d. Now remove the 10th through 85th observations. What is the range, mean, and standard deviation of each predictor in the subset of the data that remains?

# %%
auto_dropped = auto_quanti.drop(labels=range(10, 86), axis=0)
auto_dropped
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 387  27.0          4         140.0          86    2790          15.6    82
# 388  44.0          4          97.0          52    2130          24.6    82
# 389  32.0          4         135.0          84    2295          11.6    82
# 390  28.0          4         120.0          79    2625          18.6    82
# 391  31.0          4         119.0          82    2720          19.4    82
#
# [316 rows x 7 columns]

# %%
# min 
auto_dropped.min()
# Out:
# mpg               11.0
# cylinders          3.0
# displacement      68.0
# horsepower        46.0
# weight          1649.0
# acceleration       8.5
# year              70.0
# dtype: float64

# %%
# max
auto_dropped.max()
# Out:
# mpg               46.6
# cylinders          8.0
# displacement     455.0
# horsepower       230.0
# weight          4997.0
# acceleration      24.8
# year              82.0
# dtype: float64

# %%
# with the reduced data, the range is like the below:

# mpg               11.0 - 46.6
# cylinders          3.0 -8.0
# displacement      68.0 - 455.0
# horsepower        46.0 - 230.0
# weight          1649.0 - 4997.0
# acceleration       8.5 - 24.8
# year              70.0 - 82.0

# %%
auto_dropped.mean()
# Out:
# mpg               24.407595
# cylinders          5.373418
# displacement     187.512658
# horsepower       100.848101
# weight          2936.534810
# acceleration      15.717405
# year              77.136076
# dtype: float64

# %%
auto_dropped.std()
# Out:
# mpg               7.863285
# cylinders         1.654179
# displacement    100.114616
# horsepower       35.954147
# weight          811.874450
# acceleration      2.713876
# year              3.123464
# dtype: float64

# %%
# Q5-e. Using the full data set, investigate the predictors graphically, using scatterplots or other tools of your choice. Create some plots highlighting the relationships among the predictors. Comment on your findings

# %%
plt.plot('acceleration',  # x

         'weight',  # y

         data=auto_dataset, 

         linestyle='none', 

         marker='o', 

         markersize=10,

         color='blue', 

         alpha=0.5)

plt.title('Scatter Plot', fontsize=20)

plt.xlabel('acceleration', fontsize=14)

plt.ylabel('weight', fontsize=14)

plt.show()

# %% [markdown]
# It seems like there's no linear between accelearation and the weight.

# %%
plt.plot('acceleration',  # x

         'horsepower',  # y

         data=auto_dataset, 

         linestyle='none', 

         marker='o', 

         markersize=10,

         color='red', 

         alpha=0.5)

plt.title('Scatter Plot', fontsize=20)

plt.xlabel('acceleration', fontsize=14)

plt.ylabel('horsepower', fontsize=14)

plt.show()

# %% [markdown]
# The relationship between acceleration and horsepower looks like it could be linear.

# %%
plt.plot('weight',  # x

         'horsepower',  # y

         data=auto_dataset, 

         linestyle='none', 

         marker='o', 

         markersize=10,

         color='yellow', 

         alpha=0.5)

plt.title('Scatter Plot', fontsize=20)

plt.xlabel('weight', fontsize=14)

plt.ylabel('horsepower', fontsize=14)

plt.show()

# %% [markdown]
# The relationship between weight and horsepower looks like it could be linear.

# %%
# Q5-f. Suppose that we wish to predict gasmileage (mpg) on the basis of the other variables. Do your plots suggest that any of the other variables might be useful in predicting mpg? Justify your answer.

# %%
plt.plot('horsepower',  # x

         'mpg',  # y

         data=auto_dataset, 

         linestyle='none', 

         marker='o', 

         markersize=10,

         color='green', 

         alpha=0.5)

plt.title('Scatter Plot', fontsize=20)

plt.xlabel('horsepower', fontsize=14)

plt.ylabel('mpg', fontsize=14)

plt.show()

# %% [markdown]
# horsepower seems useful to predict mpg

# %%
plt.plot('displacement',  # x

         'mpg',  # y

         data=auto_dataset, 

         linestyle='none', 

         marker='o', 

         markersize=10,

         color='purple', 

         alpha=0.5)

plt.title('Scatter Plot', fontsize=20)

plt.xlabel('displacement', fontsize=14)

plt.ylabel('mpg', fontsize=14)

plt.show()

# %% [markdown]
# displacement seems useful to predict mpg

# %%
plt.plot('weight',  # x

         'mpg',  # y

         data=auto_dataset, 

         linestyle='none', 

         marker='o', 

         markersize=10,

         color='pink', 

         alpha=0.5)

plt.title('Scatter Plot', fontsize=20)

plt.xlabel('weight', fontsize=14)

plt.ylabel('mpg', fontsize=14)

plt.show()

# %% [markdown]
# weight seems useful to predict mpg
